# %%
import numpy as np
import pandas as pd
import os
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import random

# %%
# Specify the path to your uploaded text file
file_path = '/content/data.txt'

# Initialize an empty list to store the lines
lines = []

# Read the contents of the file and split into lines
with open(file_path, 'r') as file:
    for line in file:
        lines.append(line.strip())  # Remove leading/trailing whitespace if needed

# Now, 'lines' contains each line of the text file as elements in the array
print("number of lines = ", len(lines))
# Out:
# number of lines =  29401

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
cleaned_txt = []
for line in lines:
   line = line.lower()
   line = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-\\]", "", line)
   tokens = word_tokenize(line)
   words = [word for word in tokens if word.isalpha()]
   cleaned_txt+=words


print("number of words = ", len(cleaned_txt))
# Out:
# number of words =  274907

# %%
def make_markov_model(cleaned_stories, n_gram=2):
    markov_model = {}
    for i in range(len(cleaned_stories)-n_gram-1):
        curr_state, next_state = "", ""
        for j in range(n_gram):
            curr_state += cleaned_stories[i+j] + " "
            next_state += cleaned_stories[i+j+n_gram] + " "
        curr_state = curr_state[:-1]
        next_state = next_state[:-1]
        if curr_state not in markov_model:
            markov_model[curr_state] = {}
            markov_model[curr_state][next_state] = 1
        else:
            if next_state in markov_model[curr_state]:
                markov_model[curr_state][next_state] += 1
            else:
                markov_model[curr_state][next_state] = 1

    # calculating transition probabilities
    for curr_state, transition in markov_model.items():
        total = sum(transition.values())
        for state, count in transition.items():
            markov_model[curr_state][state] = count/total

    return markov_model

# %%
markov_model = make_markov_model(cleaned_txt)

# %%
print(markov_model.keys())
# Out:
# dict_keys(['chapter i', 'i in', 'in which', 'which phileas', 'phileas fogg', 'fogg and', 'and passepartout', 'passepartout accept', 'accept each', 'each other', 'other the', 'the one', 'one as', 'as master', 'master the', 'the other', 'other as', 'as man', 'man mr', 'mr phileas', 'fogg lived', 'lived in', 'in at', 'at no', 'no saville', 'saville row', 'row burlington', 'burlington gardens', 'gardens the', 'the house', 'house in', 'which sheridan', 'sheridan died', 'died in', 'in he', 'he was', 'was one', 'one of', 'of the', 'the most', 'most noticeable', 'noticeable members', 'members of', 'the reform', 'reform club', 'club though', 'though he', 'he seemed', 'seemed always', 'always to', 'to avoid', 'avoid attracting', 'attracting attention', 'attention an', 'an enigmatical', 'enigmatical personage', 'personage about', 'about whom', 'whom little', 'little was', 'was known', 'known except', 'except that', 'that he', 'was a', 'a polished', 'polished man', 'man of', 'the world', 'world 
# ...

# %%
print("number of states = ", len(markov_model.keys()))
# Out:
# number of states =  126431

# %%
print("All possible transitions from 'phileas fogg' state: \n")
print(markov_model['phileas fogg'])
# Out:
# All possible transitions from 'phileas fogg' state:
#
# ...

# %%
def generate_story(markov_model, limit=100, start='my god'):
    n = 0
    curr_state = start
    next_state = None
    story = ""
    story+=curr_state+" "
    while n<limit:
        next_state = random.choices(list(markov_model[curr_state].keys()),
                                    list(markov_model[curr_state].values()))

        curr_state = next_state[0]
        story+=curr_state+" "
        n+=1
    return story

# %%
for i in range(20):
    print(str(i)+". ", generate_story(markov_model, start="which phileas", limit=8))
# Out:
# 0.  which phileas fogg and his two companions took their places on a numerous drove of trained dogs he
# 1.  which phileas fogg astounds passepartout his servant having won twenty guineas at whist and handed them to the
# 2.  which phileas fogg and fix were roughly hustled in their civilised lives they were a bit silly or
# 3.  which phileas fogg does not have cost less than three thousand seven hundred and sixty degrees on the
# 4.  which phileas fogg and party cross the pacific railroad from ocean to ocean so say the americans and
# 5.  which phileas foggs name is once more at a premium on change phileas fogg after paying the stipulated
# 6.  which phileas fogg simply at least mr wace was able to consider our position save that there were
# 7.  which phileas fogg engages in a heap pounded into the lane that ran down to clerval we ascended
# 8.  which phileas foggs name was once a town grew a little larger each hour a little while before
# ...

# %%
print(generate_story(markov_model, start="the one", limit=100))
# Out:
# the one in this land of the as he said she turned in unfeigned astonishment nothing but the hearts of your enemies i believed myself totally unfitted for the company of a coming slowly across the stream and stopped fifty paces from the pyre but he was by the skilful guidance of my new abode but as the passage of my cousins and commended my wife in the observatory after the tenth month her father died in her be hers the punishment laid we have sinned we have been so inevitable i was delayed by an ingenious system berths were suddenly improvised and each beast have his mate she learnt to hunt us no harm he performed the graceful trick of the day had already utterly exhausted all three of the metallic giants stood about the railway station the pacific there were four or five men already assembled in his wisdom has put upon this earth for so it will be too hasty replied samuel fallentin you know india why yes replied fix who spoke cautiously a curious fascination upon mr cave promised to
# ...
